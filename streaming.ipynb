# %%
import numpy as np
import matplotlib.scatter as sct
import matplotlib.pyplot as plt
plt.style.use('seaborn')
# %matplotlib inline

# %%
from streaming_data.stream import get_data

data = get_data()[1:]
data
# Out:
#        label_id  release_id  sum_units  sum_royalty report_date  territory_id
# 1            16         546          2         0.01  2018-02-13           176
# 2            16        1663          1         0.01  2018-02-13           183
# 3            16        2015          1         0.01  2018-02-13           235
# 4            16        4253          2         0.01  2018-02-13           183
# 5            16        4253          1         0.01  2018-02-13           183
# 6            16        4681          4         0.03  2018-02-13            81
# 7            16        4681          7         0.05  2018-02-13            81
# 8            16        4690          1         0.01  2018-02-13            99
# 9            16        5612          2         0.01  2018-02-13            81
# 10           16        5791          2         0.01  2018-02-13           183
# 11           16        5791          2         0.01  2018-02-13           233
# ...

# %%
royalty_sum = data.groupby(['label_id']).sum_royalty.agg({'royalties':np.sum})

royalty_sum.plot()
# Out:
# /Users/moe/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   """Entry point for launching an IPython kernel.

# %%
units_sum = data.groupby(['report_date', 'label_id'])['sum_units'].aggregate(sum)
units_sum.plot()

# %%
#x = data.groupby(['label_id']).sum_units.agg({'sums':np.sum})
x = data['label_id'][1:]
x
# Out:
# 2           16
# 3           16
# 4           16
# 5           16
# 6           16
# 7           16
# 8           16
# 9           16
# 10          16
# 11          16
# 12          16
# 13          16
# 14          16
# 15          16
# 16          16
# 17          16
# 18          16
# 19          16
# 20          16
# 21          16
# 22          16
# 23          16
# 24          16
# 25          16
# 26          16
# 27          16
# 28          16
# 29          16
# 30          16
# 31          16
#          ...
# 24267    14916
# 24268    14916
# 24269    14916
# 24270    14916
# 24271    14916
# 24272    14916
# 24273    14916
# 24274    14928
# 24275    14928
# 24276    14928
# 24277    14954
# 24278    14954
# 24279    14960
# 24280    15048
# 24281    15048
# 24282    15127
# 24283    15128
# 24284    15145
# 24285    15145
# 24286    15181
# 24287    15287
# 24288    15310
# 24289    15329
# 24290    15349
# 24291    15403
# 24292    15403
# 24293    15403
# ...

# %%
y = data['sum_units'][1:]
y
# Out:
# 2           1
# 3           1
# 4           2
# 5           1
# 6           4
# 7           7
# 8           1
# 9           2
# 10          2
# 11          2
# 12          2
# 13         74
# 14          2
# 15          4
# 16          1
# 17          1
# 18          1
# 19         12
# 20         12
# 21         11
# 22          2
# 23          1
# 24          2
# 25          1
# 26          2
# 27          2
# 28          2
# 29          1
# 30          5
# 31          1
#          ...
# 24267       4
# 24268       2
# 24269       3
# 24270       3
# 24271       4
# 24272       4
# 24273       2
# 24274       1
# 24275       1
# 24276       1
# 24277       2
# 24278       4
# 24279       1
# 24280       5
# 24281       1
# 24282       9
# 24283       1
# 24284      10
# 24285       2
# 24286       4
# 24287       8
# 24288      20
# 24289       2
# 24290    1496
# 24291       1
# 24292       1
# 24293       2
# 24294       1
# 24295       1
# 24296       2
# ...

# %%
plt.scatter(x,y)

# %%
y
# Out:
# 2           1
# 3           1
# 4           2
# 5           1
# 6           4
# 7           7
# 8           1
# 9           2
# 10          2
# 11          2
# 12          2
# 13         74
# 14          2
# 15          4
# 16          1
# 17          1
# 18          1
# 19         12
# 20         12
# 21         11
# 22          2
# 23          1
# 24          2
# 25          1
# 26          2
# 27          2
# 28          2
# 29          1
# 30          5
# 31          1
#          ...
# 24267       4
# 24268       2
# 24269       3
# 24270       3
# 24271       4
# 24272       4
# 24273       2
# 24274       1
# 24275       1
# 24276       1
# 24277       2
# 24278       4
# 24279       1
# 24280       5
# 24281       1
# 24282       9
# 24283       1
# 24284      10
# 24285       2
# 24286       4
# 24287       8
# 24288      20
# 24289       2
# 24290    1496
# 24291       1
# 24292       1
# 24293       2
# 24294       1
# 24295       1
# 24296       2
# ...
