# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('seaborn')
# %matplotlib inline

# %%
from streaming_data.stream import get_data

data = get_data()[1:]
royalty_sum = data
# Out:
#              label_id  release_id  sum_units  sum_royalty  territory_id
# report_date
# 2018-02-13         16         546          2         0.01           176
# 2018-02-13         16        1663          1         0.01           183
# 2018-02-13         16        2015          1         0.01           235
# 2018-02-13         16        4253          2         0.01           183
# 2018-02-13         16        4253          1         0.01           183
# 2018-02-13         16        4681          4         0.03            81
# 2018-02-13         16        4681          7         0.05            81
# 2018-02-13         16        4690          1         0.01            99
# 2018-02-13         16        5612          2         0.01            81
# 2018-02-13         16        5791          2         0.01           183
# 2018-02-13         16        5791          2         0.01           233
# 2018-02-13         16        5791          2         0.01           183
# ...
